# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Aug 16 12:09:28 2023

@author: Sarang
"""

# -*- coding: utf-8 -*-
"""
Created on Thu Jun  8 21:55:40 2023
Created on Sun Jun 19 15:45:23 2022
Created on Sat Jun 18 09:12:49 2022
Created on Fri Jun 17 19:19:32 2022
Created on Wed Jun 15 18:41:19 2022
Calibration Module - 8 - Equity Module

Created on Fri Jun  3 19:14:22 2022
Created on Thu Jun  2 20:49:27 2022
Created on Thu Jun  2 00:15:25 2022
Created on Wed Jun  1 21:39:45 2022
Created on Fri May 27 07:36:59 2022

model X: OHLC based

graph version X:

notes:

    1.

@author: Sarang

"""

#-----------------------------------------------------------------------------#
model_vers = '11-2'
asset_name = "MSFT"
key_folder = 'EquityDM' # permanent
cng_direction = "POS"

model_name = "MSFT - Daily Prediction Model"

# import packages
import numpy as np
import pandas as pd
import time
import datetime
from datetime import datetime, timedelta
import yfinance as yf
import math
import pickle

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn import preprocessing
import statsmodels.formula.api as smf
import random
from stockstats import StockDataFrame
import os

import smtplib
import requests
from tsfresh import extract_features
import re

import lightgbm as lgb
import tpot

import warnings
import statistics
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=RuntimeWarning)
np.warnings.filterwarnings('ignore')

from sklearn.tree import DecisionTreeClassifier
from numpy import random as rd
import shutil

#-----------------------------------------------------------------------------#

# define constants
exp_change = 1.5 #2
min_prop = 8 # 10 50

observation_period = 46 # 365 # 240 #  >> gap_time multiplied minutes
performance_period = 1 # >> minutes
data_prep = False

start_dt = "2015-01-01"
source_file_name = "C:/Users/Sarang/Desktop/EquityDM/MSFT/Development/Calibration/src/graph.py"

#-----------------------------------------------------------------------------#
# define constants
#------------------------------------------#
run_corr_var_sel = True # run spearman correlation based variable selection
run_outlier_sample = True # using isolation forest & svm one class for removing outlier samples
run_cal_recent = True
recent_perd_rows = 8640 # 15 days when 4320 selected; number of most recent (tail) to be considered, if "max" (not applicable) all rows will be taken (usually 3000 test and 2000 test1)


run_xgb_var_imp_sel = False
run_model_eval = False
run_regression_analysis = False
run_random_rows = False # always false -- change to be studied well
run_clustering_ip = True
run_optuna_optimizer = False
optuna_trial_count = 2500

#------------------------------------------#
# start date for data extraction and prep of ABT
st_timestamp0 = str(datetime.now() - timedelta(days = 365))
st_timestamp = pd.to_datetime(st_timestamp0[0:4] + st_timestamp0[4:7] + st_timestamp0[7:10] + " 00:00:00+00:00")
# Out:
#      <input type="file" id="files-7a1e0e49-280f-4a6d-a6df-31bb4eac15e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a1e0e49-280f-4a6d-a6df-31bb4eac15e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
